# %% [markdown]
# # Exercício de Aula 5 - Análise de Dados com Pandas
#
# Neste exercício, poderá praticar alguns dos conceitos cobertos na aula
#
# Ao percorrer este notebook, irá encontrar um **???** em certos sítios. Para completar este exercício, deverá substituir todos os **???** com valores, expressões ou instruções apropriadas de forma a garantir que o notebook executa corretamente do início até ao fim.
#
# Algumas coisas para ter em mente:
#
# * Certifique-se que executa todas as células de código, de outra forma poderá obter erros como `NameError` para variáveis não definidas.
# * Não altere nomes de variáveis, não apague células nem altere outro código existente. Pode causar problemas na avaliação.
# * Em alguns casos, pode ter de adicionar algumas células de código ou novas instruções antes ou depois da linha de código contendo os **???**.
# * As questões marcadas com **(Opcional)** não são consideradas para avaliação e podem ser ignoradas, sendo apenas para desafio ou aprendizagem adicional.

# %%
import pandas as pd

# %% [markdown]
# Neste exercício, vamos analisar e trabalhar com dados de um ficheiro CSV. Vamos começar por descarregar o ficheiro CSV.

# %%
# from urllib.request import urlretrieve

# urlretrieve('https://raw.githubusercontent.com/davsimoes/mcde-pds/main/res/countries.csv',
            # 'countries.csv')

# %% [markdown]
# Vamos carregar os dados do ficheiro CSV para um dataframe Pandas.

# %%
countries_df = pd.read_csv('https://raw.githubusercontent.com/davsimoes/mcde-pds/main/res/countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# 4                           NaN        5819.495
# ..                          ...             ...
# 205                        2.60        6171.884
# 206                         NaN             NaN
# 207                        0.70        1479.147
# 208                        2.00        3689.251
# 209                        1.70        1899.775
#
# [210 rows x 6 columns]

# %% [markdown]
# **P1: Quantos países é que estão contidos no dataframe?**
#
# Dica: Use o método `.shape`.

# %%
num_countries = countries_df['location'].nunique()
print(f'O Dataframe possui {num_countries} países diferentes na coluna Location')
# Out:
# O Dataframe possui 210 países diferentes na coluna Location

# %%
print('Existem {} países no dataset'.format(num_countries))
# Out:
# Existem 210 países no dataset

# %% [markdown]
# **P2: Obtenha uma lista de continentes do dataframe**
#
# *Hint: Use o método `.unique` de uma série.*

# %%
continents = countries_df['continent'].unique()

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **P3: Qual é a população total de todos os países listados neste dataset?**

# %%
total_population = countries_df['population'].sum()

# %%
print('A população total é de {} de pessoas.'.format(int(total_population)))
# Out:
# A população total é de 7757980095 de pessoas.

# %% [markdown]
# **P: (Opcional) Qual é a esperança de vida global a nível mundial?**
#
# *Dica: Terá de retirar uma média ponderada de esperança de vida usando as populações como pesos.*

# %%
life_expec = countries_df['life_expectancy'].mean().round(2)

# %%
print(f'A média de esperança de vida global é de {life_expec} anos')
# Out:
# A média de esperança de vida global é de 73.53 anos

# %% [markdown]
# **P4: Crie um dataframe contendo os 10 países com maior população.**
#
# *Dica: Chame em sequência os métodos `sort_values` e `head`.*

# %%
most_populous_df = countries_df.sort_values(by=['population'], ascending=False)

# %%
## O pd.set_option abaixo retira a notação científica, melhorando a legibilidade do output
pd.set_option('display.float_format', lambda x: '%.1f' % x)
most_populous_df.head(10)
# Out:
#           location      continent   population  life_expectancy  \
# 41           China           Asia 1439323774.0             76.9
# 90           India           Asia 1380004385.0             69.7
# 199  United States  North America  331002647.0             78.9
# 91       Indonesia           Asia  273523621.0             71.7
# 145       Pakistan           Asia  220892331.0             67.3
# 27          Brazil  South America  212559409.0             75.9
# 141        Nigeria         Africa  206139587.0             54.7
# 15      Bangladesh           Asia  164689383.0             72.6
# 157         Russia         Europe  145934460.0             72.6
# 125         Mexico  North America  128932753.0             75.0
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                          4.3         15308.7
# 90                          0.5          6426.7
# 199                         2.8         54225.4
# 91                          1.0         11188.7
# 145                         0.6          5034.7
# 27                          2.2         14103.5
# 141                         NaN          5338.5
# 15                          0.8          3524.0
# 157                         8.1         24766.0
# 125                         1.4         17336.5

# %% [markdown]
# **P5: Adicione uma nova coluna em `countries_df` para guardar o PIB global por país (produto da população com o PIB per capita).**

# %%
countries_df['gdp'] = countries_df['gdp_per_capita'] * countries_df['population']

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0             64.8
# 1           Albania    Europe   2877800.0             78.6
# 2           Algeria    Africa  43851043.0             76.9
# 3           Andorra    Europe     77265.0             83.7
# 4            Angola    Africa  32866268.0             61.1
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0             75.4
# 206  Western Sahara    Africa    597330.0             70.3
# 207           Yemen      Asia  29825968.0             66.1
# 208          Zambia    Africa  18383956.0             63.9
# 209        Zimbabwe    Africa  14862927.0             61.5
#
#      hospital_beds_per_thousand  gdp_per_capita            gdp
# 0                           0.5          1804.0  70226221095.6
# 1                           2.9         11803.4  33967913731.8
# 2                           1.9         13913.8 610136352284.1
# 3                           NaN             NaN            NaN
# 4                           NaN          5819.5 191265082294.7
# ..                          ...             ...            ...
# 205                         2.6          6171.9 600762443000.4
# 206                         NaN             NaN            NaN
# 207                         0.7          1479.1  44116991089.3
# 208                         2.0          3689.3  67823028057.0
# 209                         1.7          1899.8  28236217141.4
#
# [210 rows x 7 columns]

# %% [markdown]
# **P: (Opcional) Crie um dataframe contendo os 10 países com menor PIB per capita, de entre os países com população superior a 100 milhões.**

# %%
big_countr = countries_df[countries_df['population'] >= 100000000].copy()
big_countr = big_countr.sort_values(by=['gdp_per_capita'], ascending=True)
big_countr.head(10)
# Out:
#         location      continent   population  life_expectancy  \
# 63      Ethiopia         Africa  114963583.0             66.6
# 15    Bangladesh           Asia  164689383.0             72.6
# 145     Pakistan           Asia  220892331.0             67.3
# 141      Nigeria         Africa  206139587.0             54.7
# 90         India           Asia 1380004385.0             69.7
# 151  Philippines           Asia  109581085.0             71.2
# 58         Egypt         Africa  102334403.0             72.0
# 91     Indonesia           Asia  273523621.0             71.7
# 27        Brazil  South America  212559409.0             75.9
# 41         China           Asia 1439323774.0             76.9
#
#      hospital_beds_per_thousand  gdp_per_capita              gdp
# 63                          0.3          1729.9   198878606248.4
# 15                          0.8          3524.0   580362750661.9
# 145                         0.6          5034.7  1112128386024.3
# 141                         NaN          5338.5  1100466702778.5
# 90                          0.5          6426.7  8868838300965.5
# 151                         1.0          7599.2   832727266159.0
# 58                          1.6         10550.2  1079649032537.0
# 91                          1.0         11188.7  3060385773322.0
# 27                          2.2         14103.5  2997821421979.9
# 41                          4.3         15308.7 22034193130919.1

# %% [markdown]
# **P6: Crie um dataframe que conta o número de países em cada continente**
#
# *Dica: Use o `groupby`, selecione a coluna `location` e agregue com `count`.*

# %%
country_counts_df = countries_df.groupby('continent')['location'].count()

# %%
country_counts_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# **P7: Crie um dataframe que mostre a população total de cada continente.**
#
# *Dica: Use o `groupby`, selecione a coluna da população e agregue com `sum`.*

# %%
continent_populations_df = countries_df.groupby('continent')['population'].sum()
continent_populations_df = continent_populations_df.sort_values(ascending=False)

# %%
continent_populations_df
# Out:
# continent
# Asia            4607388081.0
# Africa          1339423921.0
# Europe           748506210.0
# North America    591242473.0
# South America    430461090.0
# Oceania           40958320.0
# Name: population, dtype: float64

# %% [markdown]
# Vamos fazer o download de outro ficheiro CSV contendo estatísticas globais da Covid-19 stats para vários países, e ler os dados para outro dataframe Pandas.

# %%
# urlretrieve('https://raw.githubusercontent.com/davsimoes/mcde-pds/main/res/covid-countries-data.csv',
            # 'covid-countries-data.csv')

# %%
covid_data_df = pd.read_csv('https://raw.githubusercontent.com/davsimoes/mcde-pds/main/res/covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **P8: Conte o número de países para os quais os dados `total_tests` estão em falta.**
#
# *Dica: Use o método `.isna`.*

# %%
total_tests_missing = covid_data_df['total_tests'].isnull().sum()

# %%
print("Os dados para os testes totais estão em falta para {} países.".format(int(total_tests_missing)))
# Out:
# Os dados para os testes totais estão em falta para 122 países.

# %% [markdown]
# Vamos juntar os dois dataframes, e calcular mais algumas métricas.
#
# **P9: Faça a junção de `countries_df` com `covid_data_df` sobre a coluna `location`.**
#
# *Dica: Use o método `.merge` em `countries_df`.*

# %%
combined_df = pd.merge(countries_df, covid_data_df, on='location')

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0             64.8
# 1           Albania    Europe   2877800.0             78.6
# 2           Algeria    Africa  43851043.0             76.9
# 3           Andorra    Europe     77265.0             83.7
# 4            Angola    Africa  32866268.0             61.1
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0             75.4
# 206  Western Sahara    Africa    597330.0             70.3
# 207           Yemen      Asia  29825968.0             66.1
# 208          Zambia    Africa  18383956.0             63.9
# 209        Zimbabwe    Africa  14862927.0             61.5
#
#      hospital_beds_per_thousand  gdp_per_capita            gdp  total_cases  \
# 0                           0.5          1804.0  70226221095.6      38243.0
# 1                           2.9         11803.4  33967913731.8       9728.0
# 2                           1.9         13913.8 610136352284.1      45158.0
# 3                           NaN             NaN            NaN       1199.0
# 4                           NaN          5819.5 191265082294.7       2729.0
# ..                          ...             ...            ...          ...
# 205                         2.6          6171.9 600762443000.4       1046.0
# 206                         NaN             NaN            NaN        766.0
# 207                         0.7          1479.1  44116991089.3       1976.0
# 208                         2.0          3689.3  67823028057.0      12415.0
# 209                         1.7          1899.8  28236217141.4       6638.0
#
#      total_deaths  total_tests
# 0          1409.0          NaN
# 1           296.0          NaN
# 2          1525.0          NaN
# 3            53.0          NaN
# 4           109.0          NaN
# ..            ...          ...
# 205          35.0     261004.0
# 206           1.0          NaN
# 207         571.0          NaN
# 208         292.0          NaN
# 209         206.0      97272.0
#
# [210 rows x 10 columns]

# %% [markdown]
# **P10: Adicione colunas `tests_per_million`, `cases_per_million` e `deaths_per_million` em `combined_df`.**

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df['cases_per_million'] = combined_df['total_cases'] * 1e6 / combined_df['population']

# %%
combined_df['deaths_per_million'] = combined_df['total_deaths'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0             64.8
# 1           Albania    Europe   2877800.0             78.6
# 2           Algeria    Africa  43851043.0             76.9
# 3           Andorra    Europe     77265.0             83.7
# 4            Angola    Africa  32866268.0             61.1
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0             75.4
# 206  Western Sahara    Africa    597330.0             70.3
# 207           Yemen      Asia  29825968.0             66.1
# 208          Zambia    Africa  18383956.0             63.9
# 209        Zimbabwe    Africa  14862927.0             61.5
#
#      hospital_beds_per_thousand  gdp_per_capita            gdp  total_cases  \
# 0                           0.5          1804.0  70226221095.6      38243.0
# 1                           2.9         11803.4  33967913731.8       9728.0
# 2                           1.9         13913.8 610136352284.1      45158.0
# 3                           NaN             NaN            NaN       1199.0
# 4                           NaN          5819.5 191265082294.7       2729.0
# ..                          ...             ...            ...          ...
# 205                         2.6          6171.9 600762443000.4       1046.0
# 206                         NaN             NaN            NaN        766.0
# 207                         0.7          1479.1  44116991089.3       1976.0
# 208                         2.0          3689.3  67823028057.0      12415.0
# 209                         1.7          1899.8  28236217141.4       6638.0
#
#      total_deaths  total_tests  tests_per_million  cases_per_million  \
# 0          1409.0          NaN                NaN              982.4
# 1           296.0          NaN                NaN             3380.4
# 2          1525.0          NaN                NaN             1029.8
# 3            53.0          NaN                NaN            15518.0
# 4           109.0          NaN                NaN               83.0
# ..            ...          ...                ...                ...
# 205          35.0     261004.0             2681.4               10.7
# 206           1.0          NaN                NaN             1282.4
# 207         571.0          NaN                NaN               66.3
# 208         292.0          NaN                NaN              675.3
# 209         206.0      97272.0             6544.6              446.6
#
#      deaths_per_million
# 0                  36.2
# 1                 102.9
# 2                  34.8
# 3                 686.0
# 4                   3.3
# ..                  ...
# 205                 0.4
# 206                 1.7
# 207                19.1
# 208                15.9
# 209                13.9
#
# [210 rows x 13 columns]

# %% [markdown]
# **P11: Crie um dataframe com os 10 países com o maior número de testes por milhão de habitantes.**

# %%
highest_tests_df = combined_df.sort_values(by=['tests_per_million'], ascending=False).head(10)

# %%
highest_tests_df
# Out:
#                  location      continent  population  life_expectancy  \
# 197  United Arab Emirates           Asia   9890400.0             78.0
# 14                Bahrain           Asia   1701583.0             77.3
# 115            Luxembourg         Europe    625976.0             82.2
# 122                 Malta         Europe    441539.0             82.5
# 53                Denmark         Europe   5792203.0             80.9
# 96                 Israel           Asia   8655541.0             83.0
# 89                Iceland         Europe    341250.0             83.0
# 157                Russia         Europe 145934460.0             72.6
# 199         United States  North America 331002647.0             78.9
# 10              Australia        Oceania  25499881.0             83.4
#
#      hospital_beds_per_thousand  gdp_per_capita              gdp  total_cases  \
# 197                         1.2         67293.5   665559464263.2      71540.0
# 14                          2.0         43290.7    73662727686.0      52440.0
# 115                         4.5         94278.0    59015743418.8       7928.0
# 122                         4.5         36513.3    16122056124.1       1931.0
# 53                          2.5         46682.5   270394603430.5      17195.0
# 96                          3.0         33132.3   286778154185.1     122539.0
# 89                          2.9         46483.0    15862309417.5       2121.0
# 157                         8.1         24766.0  3614206123374.8    1005000.0
# 199                         2.8         54225.4 17948766160755.6    6114406.0
# 10                          3.8         44648.7  1138536791803.5      25923.0
#
#      total_deaths  total_tests  tests_per_million  cases_per_million  \
# 197         387.0    7177430.0           725696.6             7233.3
# 14          190.0    1118837.0           657527.1            30818.4
# 115         124.0     385820.0           616349.5            12665.0
# 122          13.0     188539.0           427004.2             4373.3
# 53          626.0    2447911.0           422621.8             2968.6
# 96          969.0    2353984.0           271962.7            14157.3
# 89           10.0      88829.0           260304.8             6215.4
# 157       17414.0   37176827.0           254750.2             6886.7
# 199      185744.0   83898416.0           253467.5            18472.4
# 10          663.0    6255797.0           245326.5             1016.6
#
#      deaths_per_million
# 197                39.1
# 14                111.7
# 115               198.1
# 122                29.4
# 53                108.1
# 96                112.0
# 89                 29.3
# 157               119.3
# 199               561.2
# 10                 26.0

# %% [markdown]
# **P12: Crie um dataframe com os 10 países que têm mais casos positivos por milhão de habitantes.**

# %%
highest_cases_df = combined_df.sort_values(by=['cases_per_million'], ascending=False).head(10)

# %%
highest_cases_df
# Out:
#           location      continent  population  life_expectancy  \
# 155          Qatar           Asia   2881060.0             80.2
# 14         Bahrain           Asia   1701583.0             77.3
# 147         Panama  North America   4314768.0             78.5
# 40           Chile  South America  19116209.0             80.2
# 162     San Marino         Europe     33938.0             85.0
# 9            Aruba  North America    106766.0             76.3
# 105         Kuwait           Asia   4270563.0             75.5
# 150           Peru  South America  32971846.0             76.7
# 27          Brazil  South America 212559409.0             75.9
# 199  United States  North America 331002647.0             78.9
#
#      hospital_beds_per_thousand  gdp_per_capita              gdp  total_cases  \
# 155                         1.2        116935.6   336898479736.0     119206.0
# 14                          2.0         43290.7    73662727686.0      52440.0
# 147                         2.3         22267.0    96077098702.4      94084.0
# 40                          2.1         22767.0   435219437602.7     414739.0
# 162                         3.8         56861.5     1929764568.9        735.0
# 9                           NaN         35973.8     3840776702.2       2211.0
# 105                         2.0         65530.5   279852286682.3      86478.0
# 150                         1.6         12236.7   403466785779.3     663437.0
# 27                          2.2         14103.5  2997821421979.9    3997865.0
# 199                         2.8         54225.4 17948766160755.6    6114406.0
#
#      total_deaths  total_tests  tests_per_million  cases_per_million  \
# 155         199.0     634745.0           220316.5            41375.7
# 14          190.0    1118837.0           657527.1            30818.4
# 147        2030.0     336345.0            77952.0            21805.1
# 40        11344.0    2458762.0           128621.8            21695.7
# 162          42.0          NaN                NaN            21657.1
# 9            12.0          NaN                NaN            20708.8
# 105         535.0     621616.0           145558.3            20249.8
# 150       29259.0     584232.0            17719.1            20121.3
# 27       123780.0    4797948.0            22572.3            18808.2
# 199      185744.0   83898416.0           253467.5            18472.4
#
#      deaths_per_million
# 155                69.1
# 14                111.7
# 147               470.5
# 40                593.4
# 162              1237.6
# 9                 112.4
# 105               125.3
# 150               887.4
# 27                582.3
# 199               561.2

# %% [markdown]
# **P13: Crie um dataframe com os 10 países que têm mais casos de morte por milhão de habitantes**

# %%
highest_deaths_df = combined_df.sort_values(by=['deaths_per_million'], ascending=False).head(10)

# %%
highest_deaths_df
# Out:
#            location      continent  population  life_expectancy  \
# 162      San Marino         Europe     33938.0             85.0
# 150            Peru  South America  32971846.0             76.7
# 18          Belgium         Europe  11589616.0             81.6
# 3           Andorra         Europe     77265.0             83.7
# 177           Spain         Europe  46754783.0             83.6
# 198  United Kingdom         Europe  67886004.0             81.3
# 40            Chile  South America  19116209.0             80.2
# 97            Italy         Europe  60461828.0             83.5
# 27           Brazil  South America 212559409.0             75.9
# 182          Sweden         Europe  10099270.0             82.8
#
#      hospital_beds_per_thousand  gdp_per_capita             gdp  total_cases  \
# 162                         3.8         56861.5    1929764568.9        735.0
# 150                         1.6         12236.7  403466785779.3     663437.0
# 18                          5.6         42658.6  494396514946.8      85817.0
# 3                           NaN             NaN             NaN       1199.0
# 177                         3.0         34272.4 1602396754697.9     479554.0
# 198                         2.5         39753.2 2698688881197.0     338676.0
# 40                          2.1         22767.0  435219437602.7     414739.0
# 97                          3.2         35220.1 2129470660953.6     271515.0
# 27                          2.2         14103.5 2997821421979.9    3997865.0
# 182                         2.2         46949.3  474153485323.4      84532.0
#
#      total_deaths  total_tests  tests_per_million  cases_per_million  \
# 162          42.0          NaN                NaN            21657.1
# 150       29259.0     584232.0            17719.1            20121.3
# 18         9898.0    2281853.0           196887.7             7404.6
# 3            53.0          NaN                NaN            15518.0
# 177       29194.0    6416533.0           137238.0            10256.8
# 198       41514.0   13447568.0           198090.4             4988.9
# 40        11344.0    2458762.0           128621.8            21695.7
# 97        35497.0    5214766.0            86248.9             4490.7
# 27       123780.0    4797948.0            22572.3            18808.2
# 182        5820.0          NaN                NaN             8370.1
#
#      deaths_per_million
# 162              1237.6
# 150               887.4
# 18                854.0
# 3                 686.0
# 177               624.4
# 198               611.5
# 40                593.4
# 97                587.1
# 27                582.3
# 182               576.3

# %% [markdown]
# **(Opcional) P: Conte o número de países que constam em ambas as listas "maior número de testes por milhão" e "maior número de casos por milhão".**

# %%
highest_tests_locations = highest_tests_df[['location', 'tests_per_million', 'cases_per_million']]
highest_cases_locations = highest_cases_df[['location', 'tests_per_million', 'cases_per_million']]

# %%
countr_tests_cases = pd.merge(highest_tests_locations, highest_cases_locations, on='location', how='inner')
countr_tests_cases = countr_tests_cases.drop(columns=['tests_per_million_y', 'cases_per_million_y'])
countr_tests_cases
# Out:
#         location  tests_per_million_x  cases_per_million_x
# 0        Bahrain             657527.1              30818.4
# 1  United States             253467.5              18472.4

# %%
print(f'Existem apenas {countr_tests_cases.shape[0]} países que aparecem em ambas as listas')
# Out:
# Existem apenas 2 países que aparecem em ambas as listas

# %% [markdown]
# **(Opcional) P: Conte o número de países que constam em ambas as listas "20 países com o menor PIB per capita" e "20 países com o menor número de camas de hospital por milhar de habitantes". Ao criar a lista, considere apenas países com uma população superior a 10 milhões.**

# %%
other_countr = combined_df[combined_df['gdp_per_capita'] >= 10000000].copy()

# %%
small_gdp = other_countr.sort_values(by=['gdp_per_capita'], ascending=True).head(20)
small_hosp = other_countr.sort_values(by=['hospital_beds_per_thousand'], ascending=True).head(20)

# %%
countr_pib_hosp = pd.merge(small_gdp, small_hosp, on='location', how='inner')

# %%
print(f'{countr_pib_hosp.location.nunique()} países aparecem em ambas as listas')
# Out:
# 0 países aparecem em ambas as listas
